# %%
import numpy as np
import pandas as pd
import pickle

# %%
bus_data_path = 'data/yelp_academic_dataset_business.json'
df = pd.read_json(bus_data_path, lines=True)
df_open = df[df['is_open']==1]

df_restaurants = df_open.copy()
df_restaurants = df_restaurants[df_restaurants.categories.notna()]
df_restaurants = df_restaurants[df_restaurants.categories.str.contains("Restaurants")]

# %%
df_rest_filter_city = df_restaurants[(df_restaurants.city == 'Boston') & (df_restaurants['review_count'] < 150) & (df_restaurants['review_count'] > 120) ].head(20)

# %%
df_rest_filter_default = df_restaurants[(df_restaurants.city == 'Boston') & (df_restaurants.name == 'Parish Cafe and Bar') | (df_restaurants.name == 'Bistro du Midi')]

# %%
df_rest_filter = pd.concat([df_rest_filter_city, df_rest_filter_default])

# %%
df_rest_filter
# Out:
#                   business_id                          name  \
# 1014   HNY4r-VnJq9JlnQQfdnyZQ           Fin's Sushi & Grill
# 1206   ZjizmUFYq7NP8N-FAbtzFw                     Herrera's
# 1474   ENCkRJI7lC_Gwyjkb94Mew           The Boston Chipyard
# 1508   oYpQs22iUr68hSiTh7pMRA           Restaurante Cesaria
# 2991   L3Vp0LhPn1DMKtGillUvgQ                      Assaggio
# 8320   BO4Usu_YSE7jlmchGMeVcw             Shin Hakata Ramen
# 10583  THeSIOFvgOMoq7_iXQxFCw    Rail Stop Restaurant & Bar
# 11816  1znX5qwB-aMCgJepnDHQeg             Back Bay Sandwich
# 12398  a-EQKCGPirfEd33MkbD4ug            QDOBA Mexican Eats
# 13088  Jmyya_ylt3Bks4NTcyWgEg                          Zuma
# 13521  W0Lmpe7yIVercq9ouNzrxA            Lower Mills Tavern
# 14745  XgwuAwl2yLDF5hv611NKLA                       Sorelle
# 15212  XFykgL-jVwhaiq4w1LtyEA          Cappy’s Pizza & Subs
# 16234  a8qD4rxFb-v2I6YR71HLiQ                     honeygrow
# 16538  gZE88NYQbY3bQG87tjvQkw                  Andre's Cafe
# 16788  SOaE-yGSlrialvKEKP0Abw              Num Pang Kitchen
# 17662  pzCrO7RatLAB9ThsOSRu9A            Stats Bar & Grille
# 18686  kM6nMBQYaJlaDK2xorBV1A  Shaking Crab - Boston Common
# 19503  e4CjMQOnUT4JxuS7PPm0Cw              Milk Street Cafe
# 22419  8VHzD_vxEmeyZQZUIgpLCA                        B.GOOD
# 9057   _QUh5vFHSuw8R_uiFZ7XKQ           Parish Cafe and Bar
# 24376  l45r09qD9iIkQn9KoKKfuw                Bistro du Midi
#
#                            address    city state postal_code   latitude  \
# 1014                62 Boylston St  Boston    MA       02116  42.352114
# 1206                  11 Temple Pl  Boston    MA       02111  42.355270
# 1474                 Quincy Market  Boston    MA       02109  42.360247
# 1508                266 Bowdoin St  Boston    MA       02122  42.306897
{'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 16538  {'WiFi': 'u'free'', 'Alcohol': 'u'none'', 'Res...
# 16788  {'WiFi': ''no'', 'RestaurantsReservations': 'F...
# 17662  {'WiFi': ''free'', 'BusinessAcceptsCreditCards...
# 18686  {'BusinessAcceptsBitcoin': 'False', 'Restauran...
# 19503  {'GoodForKids': 'True', 'BusinessParking': '{'...
# 22419  {'RestaurantsReservations': 'False', 'Restaura...
# 9057   {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 24376  {'GoodForKids': 'False', 'RestaurantsTakeOut':...
#
#                                               categories  \
# 1014                   Restaurants, Japanese, Sushi Bars
# 1206                         Restaurants, Mexican, Delis
# 1474                         Food, Bakeries, Restaurants
# 1508   Event Planning & Services, Caterers, Restauran...
# 2991                       Restaurants, Italian, Seafood
# 8320               Restaurants, Japanese, Ramen, Noodles
# 10583  British, Steakhouses, Lounges, Bars, American ...
# 11816  Sandwiches, Breakfast & Brunch, Restaurants, Food
# 12398  Caterers, Mexican, Restaurants, Fast Food, Eve...
# 13088  Nightlife, Sushi Bars, Cocktail Bars, Restaura...
# 13521  Coffee & Tea, Nightlife, Restaurants, Desserts...
# 14745   Restaurants, Bakeries, Coffee & Tea, Cafes, Food
# 15212  Restaurants, Greek, Caterers, Mediterranean, S...
# 16234  Noodles, Restaurants, Food, Do-It-Yourself Foo...
# 16538  Ethnic Food, Restaurants, Mediterranean, Speci...
# 16788  Sandwiches, Asian Fusion, Soup, Cambodian, Sal...
# 17662  Bars, American (Traditional), Burgers, Restaur...
# 18686      Seafood, Cajun/Creole, Restaurants, Soul Food
# 19503  Vegetarian, Sushi Bars, Sandwiches, Restaurant...
# 22419  Restaurants, American (Traditional), Food, San...
# 9057   Restaurants, Desserts, American (New), Sandwic...
# 24376  Bars, French, Food, Nightlife, Restaurants, De...
#
#                                                    hours
# 1014   {'Monday': '11:30-22:30', 'Tuesday': '11:30-22...
# 1206                                                None
# 1474   {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 1508   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 2991   {'Thursday': '16:0-0:0', 'Friday': '16:0-21:30...
# 8320   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 10583                           {'Sunday': '11:30-16:0'}
# 11816  {'Monday': '6:0-17:0', 'Tuesday': '6:0-17:0', ...
# 12398  {'Monday': '0:0-0:0', 'Tuesday': '10:30-20:0',...
# 13088  {'Monday': '17:30-23:0', 'Tuesday': '17:30-23:...
# 13521  {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...
# 14745  {'Monday': '6:30-18:0', 'Tuesday': '6:30-18:0'...
# 15212  {'Monday': '6:30-2:0', 'Tuesday': '6:30-2:0', ...
# 16234  {'Monday': '0:0-0:0', 'Tuesday': '10:30-22:0',...
# 16538  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 16788                            {'Monday': '11:0-21:0'}
# 17662  {'Monday': '11:0-1:0', 'Tuesday': '11:0-1:0', ...
# 18686  {'Monday': '0:0-0:0', 'Tuesday': '12:0-21:0', ...
# 19503  {'Monday': '0:0-0:0', 'Tuesday': '7:0-15:0', '...
# 22419  {'Monday': '0:0-0:0', 'Tuesday': '7:0-20:0', '...
# 9057                                                None
# 24376  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
